# %% [markdown]
# # Example of LIF model

# %%
import brainmodels
import brainpy as bp

# %%
group = bp.math.jit(brainmodels.neurons.LIF(100, monitors=['V']))

# %%
group.run(duration=200., inputs=('input', 26.), report=0.1)
bp.visualize.line_plot(group.mon.ts, group.mon.V, show=True)
# Out:
# Compilation used 1.3184 s.
# Start running ...
# Run 10.0% used 0.003 s.
# Run 20.0% used 0.006 s.
# Run 30.0% used 0.009 s.
# Run 40.0% used 0.012 s.
# Run 50.0% used 0.015 s.
# Run 60.0% used 0.018 s.
# Run 70.0% used 0.021 s.
# Run 80.0% used 0.024 s.
# Run 90.0% used 0.027 s.
# Run 100.0% used 0.030 s.
# Simulation is done in 0.030 s.

# %%
group.run(duration=(200, 400.), report=0.1)
bp.visualize.line_plot(group.mon.ts, group.mon.V, show=True)
# Out:
# Compilation used 0.0000 s.
# Start running ...
# Run 10.0% used 0.004 s.
# Run 20.0% used 0.006 s.
# Run 30.0% used 0.007 s.
# Run 40.0% used 0.009 s.
# Run 50.0% used 0.010 s.
# Run 60.0% used 0.012 s.
# Run 70.0% used 0.014 s.
# Run 80.0% used 0.016 s.
# Run 90.0% used 0.017 s.
# Run 100.0% used 0.019 s.
# Simulation is done in 0.019 s.
