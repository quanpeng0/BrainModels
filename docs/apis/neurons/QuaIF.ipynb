# %% [markdown]
# # Example of QuaIF model

# %%
import brainmodels
import brainpy as bp

# %%
group = brainmodels.neurons.QuaIF(1, monitors=['V'])

# %%
group.run(duration=200., inputs=('input', 20.), report=0.1)
bp.visualize.line_plot(group.mon.ts, group.mon.V, show=True)
# Out:
# Compilation used 0.0010 s.
# Start running ...
# Run 10.0% used 0.010 s.
# Run 20.0% used 0.021 s.
# Run 30.0% used 0.033 s.
# Run 40.0% used 0.044 s.
# Run 50.0% used 0.055 s.
# Run 60.0% used 0.066 s.
# Run 70.0% used 0.076 s.
# Run 80.0% used 0.087 s.
# Run 90.0% used 0.097 s.
# Run 100.0% used 0.108 s.
# Simulation is done in 0.108 s.

# %%
group.run(duration=(200, 400.), report=0.1)
bp.visualize.line_plot(group.mon.ts, group.mon.V, show=True)
# Out:
# Compilation used 0.0000 s.
# Start running ...
# Run 10.0% used 0.011 s.
# Run 20.0% used 0.021 s.
# Run 30.0% used 0.030 s.
# Run 40.0% used 0.039 s.
# Run 50.0% used 0.049 s.
# Run 60.0% used 0.059 s.
# Run 70.0% used 0.068 s.
# Run 80.0% used 0.078 s.
# Run 90.0% used 0.087 s.
# Run 100.0% used 0.099 s.
# Simulation is done in 0.100 s.
